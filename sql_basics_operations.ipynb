# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:root@localhost

# %%
# %%sql
# CREATE DATABASE mydb;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# (mysql.connector.errors.DatabaseError) 1007 (HY000): Can't create database 'mydb'; database exists
# [SQL: CREATE DATABASE mydb;]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
# %%sql
# USE mydb;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# create database learning;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# (mysql.connector.errors.DatabaseError) 1007 (HY000): Can't create database 'learning'; database exists
# [SQL: create database learning;]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
# %%sql
# use learning
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# create table test ( Sno int , name varchar(100));
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# (mysql.connector.errors.ProgrammingError) 1050 (42S01): Table 'test' already exists
# [SQL: create table test ( Sno int , name varchar(100));]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 2 rows affected.
# [(1, 'T B guru'), (2, 'Akash')]

# %%
# %%sql
# insert into test(Sno,name)values(1,'Guru');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# insert into test(Sno,name)values(2,'Akash');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# update test set name = 'T B guru' where sno =1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 2 rows affected.
# []

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 4 rows affected.
# [(1, 'T B guru'), (2, 'Akash'), (1, 'T B guru'), (2, 'Akash')]

# %%
# %%sql
# delete from test where sno = 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 2 rows affected.
# []

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 2 rows affected.
# [(2, 'Akash'), (2, 'Akash')]

# %%
# %%sql
# truncate table test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# drop table test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []
